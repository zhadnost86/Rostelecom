# %%
import pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge, LinearRegression
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier

df = pandas.read_excel('input0.xlsx')
df.drop(columns=['Unnamed: 0'],inplace = True) 
#df[' '] = pd.Series(np.random.randn(len(df['Количество дней договора'])), index=df.index)

df.head(5)
# Out:
#    Дата снятия системная  Дата снятия  Номер устройства_  \
# 0                    1.0     0.073248           0.186054
# 1                    1.0     0.073248           0.626696
# 2                    1.0     0.073248           0.779978
# 3                    1.0     0.073248           0.604250
# 4                    1.0     0.073248           0.272339
#
#    Номер основного устройства_  Номер сокращенный (для БМ)   РЦ  \
# 0                     0.294134                    0.186054  1.0
# 1                     0.717491                    0.626696  1.0
# 2                     0.777913                    0.779978  1.0
# 3                     0.945931                    0.604250  1.0
# 4                     0.777913                    0.272339  1.0
#
#    Тарифный план     Адрес    № дог.  Дата договора  ...  \
# 0       0.160000  0.074776  0.573687       0.643283  ...
# 1       0.296667  0.264207  0.459298       0.514206  ...
# 2       0.436667  0.929212  0.750685       0.795160  ...
# ...

# %%
cols = df.columns.tolist()
cols = cols[-1:] + cols[:-1]
df = df[cols]
df[' '] = pd.Series(np.random.randn(len(df['Количество дней договора'])), index=df.index)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11718 entries, 0 to 11717
# Data columns (total 42 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Количество дней договора                           11718 non-null  float64
#  1   Дата снятия системная                              11718 non-null  float64
#  2   Дата снятия                                        11718 non-null  float64
#  3   Номер устройства_                                  11718 non-null  float64
#  4   Номер основного устройства_                        11718 non-null  float64
#  5   Номер сокращенный (для БМ)                         11718 non-null  float64
#  6   РЦ                                                 11718 non-null  float64
#  7   Тарифный план                                      11718 non-null  float64
# ...

# %%
cols = [col for col in df if col != 'Количество дней договора'] + ['Количество дней договора']
df = df[cols]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11718 entries, 0 to 11717
# Data columns (total 42 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Дата снятия системная                              11718 non-null  float64
#  1   Дата снятия                                        11718 non-null  float64
#  2   Номер устройства_                                  11718 non-null  float64
#  3   Номер основного устройства_                        11718 non-null  float64
#  4   Номер сокращенный (для БМ)                         11718 non-null  float64
#  5   РЦ                                                 11718 non-null  float64
#  6   Тарифный план                                      11718 non-null  float64
#  7   Адрес                                              11718 non-null  float64
# ...

# %%
df[''] = ''
df['']
# Out:
# 0
# 1
# 2
# 3
# 4
#         ..
# 11713
# 11714
# 11715
# 11716
# 11717
# Name: , Length: 11718, dtype: object

# %%
df.to_excel("input_С_Отделёнными_input_output.xlsx")
