# %%
import pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge, LinearRegression
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

# %%
df = pandas.read_excel('input0.xlsx')

# %%
df.head(5)
# Out:
#    Unnamed: 0  Дата снятия системная  Дата снятия  Номер устройства_  \
# 0           0                    1.0     0.073248           0.186054
# 1           1                    1.0     0.073248           0.626696
# 2           2                    1.0     0.073248           0.779978
# 3           3                    1.0     0.073248           0.604250
# 4           4                    1.0     0.073248           0.272339
#
#    Номер основного устройства_  Номер сокращенный (для БМ)   РЦ  \
# 0                     0.294134                    0.186054  1.0
# 1                     0.717491                    0.626696  1.0
# 2                     0.777913                    0.779978  1.0
# 3                     0.945931                    0.604250  1.0
# 4                     0.777913                    0.272339  1.0
#
#    Тарифный план     Адрес    № дог.  ...  Дата подключения системная  \
# 0       0.160000  0.074776  0.573687  ...                    0.654944
# 1       0.296667  0.264207  0.459298  ...                    0.531188
# 2       0.436667  0.929212  0.750685  ...                    0.802256
# 3       0.673333  0.175474  0.497386  ...                    0.574983
# 4       0.090000  0.929212  0.750685  ...                    0.802256
#
#    Код агента  Тип дилера  Дилер из наряда на подключение  \
# 0    0.891304         0.4                        0.152074
# 1    0.891304         0.4                        0.884793
# 2    0.891304         0.4                        0.442396
# 3    0.891304         0.4                        0.907834
# 4    0.891304         0.4                        0.442396
#
#    Наименование дилера подключения  \
# 0                         0.133663
# 1                         0.737624
# 2                         0.138614
# 3                         0.985149
# 4                         0.138614
#
#    оператор автор заявки подключения (оператор ЛИРА)  \
# 0                                           0.218391
# 1                                           0.409962
# 2                                           0.218391
# 3                                           0.038314
# 4                                           0.218391
#
#    канал продаж из Лиры при подключении  \
# 0                               1.00000
# 1                               0.34375
# 2                               1.00000
# 3                               0.34375
# 4                               1.00000
#
#    Канал (группа) поступления (данные из Лиры)  \
# 0                                          0.4
# 1                                          0.4
# 2                                          0.4
# 3                                          0.6
# 4                                          0.4
#
#    Канал поступления ЕИССД (данные из Лиры )  Количество дней договора
# 0                                   0.153846                  0.940034
# 1                                   0.153846                  0.086432
# 2                                   0.153846                  0.707873
# 3                                   1.000000                  0.068007
# 4                                   0.153846                  0.707873
#
# [5 rows x 42 columns]

# %%
df.drop(['Unnamed: 0'],axis=1,inplace = True)

# %%
df.head(5)
# Out:
#    Дата снятия системная  Дата снятия  Номер устройства_  \
# 0                    1.0     0.073248           0.186054
# 1                    1.0     0.073248           0.626696
# 2                    1.0     0.073248           0.779978
# 3                    1.0     0.073248           0.604250
# 4                    1.0     0.073248           0.272339
#
#    Номер основного устройства_  Номер сокращенный (для БМ)   РЦ  \
# 0                     0.294134                    0.186054  1.0
# 1                     0.717491                    0.626696  1.0
# 2                     0.777913                    0.779978  1.0
# 3                     0.945931                    0.604250  1.0
# 4                     0.777913                    0.272339  1.0
#
#    Тарифный план     Адрес    № дог.  Дата договора  ...  \
# 0       0.160000  0.074776  0.573687       0.643283  ...
# 1       0.296667  0.264207  0.459298       0.514206  ...
# 2       0.436667  0.929212  0.750685       0.795160  ...
# 3       0.673333  0.175474  0.497386       0.916170  ...
# 4       0.090000  0.929212  0.750685       0.795160  ...
#
#    Дата подключения системная  Код агента  Тип дилера  \
# 0                    0.654944    0.891304         0.4
# 1                    0.531188    0.891304         0.4
# 2                    0.802256    0.891304         0.4
# 3                    0.574983    0.891304         0.4
# 4                    0.802256    0.891304         0.4
#
#    Дилер из наряда на подключение  Наименование дилера подключения  \
# 0                        0.152074                         0.133663
# 1                        0.884793                         0.737624
# 2                        0.442396                         0.138614
# 3                        0.907834                         0.985149
# 4                        0.442396                         0.138614
#
#    оператор автор заявки подключения (оператор ЛИРА)  \
# 0                                           0.218391
# 1                                           0.409962
# 2                                           0.218391
# 3                                           0.038314
# 4                                           0.218391
#
#    канал продаж из Лиры при подключении  \
# 0                               1.00000
# 1                               0.34375
# 2                               1.00000
# 3                               0.34375
# 4                               1.00000
#
#    Канал (группа) поступления (данные из Лиры)  \
# 0                                          0.4
# 1                                          0.4
# 2                                          0.4
# 3                                          0.6
# 4                                          0.4
#
#    Канал поступления ЕИССД (данные из Лиры )  Количество дней договора
# 0                                   0.153846                  0.940034
# 1                                   0.153846                  0.086432
# 2                                   0.153846                  0.707873
# 3                                   1.000000                  0.068007
# 4                                   0.153846                  0.707873
#
# [5 rows x 41 columns]

# %%
df = df.reindex(columns=sorted(df.columns))
df = df.reindex(columns=(list(['Количество дней договора'] + [a for a in df.columns if a != 'Количество дней договора'])))

# %%
df.head()
# Out:
#    Количество дней договора  Mac-адрес приставки Sdp  Sdp статус     Адрес  \
# 0                  0.940034                 0.158809    1.000000  0.074776
# 1                  0.086432                 1.000000    0.666667  0.264207
# 2                  0.707873                 1.000000    0.666667  0.929212
# 3                  0.068007                 1.000000    0.666667  0.175474
# 4                  0.707873                 0.880217    1.000000  0.929212
#
#    Группа ТП СПД  Дата договора  Дата подключения  Дата подключения системная  \
# 0            1.0       0.643283          0.657199                    0.654944
# 1            1.0       0.514206          0.533686                    0.531188
# 2            1.0       0.795160          0.803831                    0.802256
# 3            1.0       0.916170          0.577279                    0.574983
# 4            1.0       0.795160          0.803831                    0.802256
#
#    Дата снятия  Дата снятия системная  ...  Серийный номер приставки Sdp  \
# 0     0.073248                    1.0  ...                      0.216941
# 1     0.073248                    1.0  ...                      0.999765
# 2     0.073248                    1.0  ...                      0.999765
# 3     0.073248                    1.0  ...                      0.999765
# 4     0.073248                    1.0  ...                      0.060000
#
#      Сх/вкл  Сх/вкл осн устройства  Тарифные опции  Тарифный план  Технология  \
# 0  0.777778                    0.2        0.250746       0.160000    0.666667
# 1  0.666667                    0.2        1.000000       0.296667    0.666667
# 2  0.666667                    0.2        1.000000       0.436667    0.666667
# 3  0.666667                    0.2        1.000000       0.673333    0.666667
# 4  0.777778                    0.2        0.537313       0.090000    0.666667
#
#    Тип дилера  канал продаж из Лиры при подключении  \
# 0         0.4                               1.00000
# 1         0.4                               0.34375
# 2         0.4                               1.00000
# 3         0.4                               0.34375
# 4         0.4                               1.00000
#
#    оператор автор заявки подключения (оператор ЛИРА)    № дог.
# 0                                           0.218391  0.573687
# 1                                           0.409962  0.459298
# 2                                           0.218391  0.750685
# 3                                           0.038314  0.497386
# 4                                           0.218391  0.750685
#
# [5 rows x 41 columns]

# %%
forest = RandomForestRegressor()
X = df.values[:, 1:40]
Y = df.values[:, 0]
trainX, testX, trainY, testY = train_test_split( X, Y, test_size = 0.3)
forest.fit(trainX, trainY)
print('Accuracy: \n', forest.score(testX, testY))
pred = forest.predict(testX)
# Out:
# Accuracy:
#  0.9156720791745548
